# %% [markdown]
# <a href="https://colab.research.google.com/github/condron78/JoannCondron_DTSC3020_summer2026/blob/main/Copy_of_Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3
#
# **Course:** DTSC 3020 — Introduction to Computation with Python
# **Lesson:** 3 — Python Data Structures
# **Points:** 50 (4 questions)
#
# ---
#
# ## Before you start
#
# Before working on the assignment, make your own copy of the notebook by going to File → Save a copy in Drive. Then complete the assignment in your own copy.
#
#
# ## How to use this notebook
#
# 1. Read each **question** (markdown cell) carefully.
# 2. Write your answer in the **code cell** that follows it.
# 3. Run the cell with `Shift + Enter` to see the output.
# 4. If you get an error, read the message, fix the code, and run it again.
#
#
# ---
# ## How to submit
#
# *You will submit by pushing this notebook to your GitHub account and then pasting the GitHub link in Canvas.*
# In Colab, click **File → Save a copy in GitHub**. Once the notebook is showing on GitHub, click the address bar of your browser and copy the full URL. Paste the link in Canvas.

# %% [markdown]
# ## Question 1 — Lists: Creating, Modifying, Indexing, and Slicing  *(13 points)*
#
# Practice building a list, changing its contents, and pulling out items by position.
#
# ### What to do
# 1. Create a list called `shopping_cart` with these four items: `"milk"`, `"bread"`, `"eggs"`, `"apples"`. Print the list.
# 2. **Add** the item `"coffee"` to the end of the list using `.append(...)`, then print the list.
# 3. **Change** the first item to `"almond milk"` using indexing, then print the list.
# 4. **Remove** the item `"bread"` using `.remove(...)`, then print the list.
# 5. A list of daily sales is provided in the code cell: `weekly_sales = [120, 150, 90, 200, 175, 80, 130]`. Using indexing and slicing, print each of the following, labeled so the output is readable:
#    - the sales for the **first** day
#    - the sales for the **last** day (use a negative index)
#    - the **first three** days
#    - the **last two** days
#
# ### Hints
# - Create a list with square brackets: `my_list = ["a", "b", "c"]`.
# - Indexing: `my_list[0]` is the first item, `my_list[-1]` is the last.
# - Slicing: `weekly_sales[0:3]` gives the first three items; the start index is included, the end index is not.
# - Label outputs by passing text first: `print("First day:", weekly_sales[0])`.

# %%
weekly_sales = [120, 150, 90, 200, 175, 80, 130]

# Write your answer here
# Part 1 — Create and print the list
shopping_cart = ["milk", "bread", "eggs", "apples"]
print("Original list:", shopping_cart)

# Part 2 — Append "coffee"
shopping_cart.append("coffee")
print("After append:", shopping_cart)

# Part 3 — Change the first item
shopping_cart[0] = "almond milk"
print("After update:", shopping_cart)

# Part 4 — Remove "bread"
shopping_cart.remove("bread")
print("After remove:", shopping_cart)

# Part 5 — Indexing and slicing weekly_sales
weekly_sales = [120, 150, 90, 200, 175, 80, 130]

print("\nFirst day:      ", weekly_sales[0])
print("Last day:       ", weekly_sales[-1])
print("First three days:", weekly_sales[0:3])
print("Last two days:  ", weekly_sales[-2:])
# Out:
# Original list: ['milk', 'bread', 'eggs', 'apples']
# After append: ['milk', 'bread', 'eggs', 'apples', 'coffee']
# After update: ['almond milk', 'bread', 'eggs', 'apples', 'coffee']
# After remove: ['almond milk', 'eggs', 'apples', 'coffee']
#
# First day:       120
# Last day:        130
# First three days: [120, 150, 90]
# Last two days:   [80, 130]

# %% [markdown]
# ## Question 2 — Tuples and the List vs Tuple Difference  *(12 points)*
#
# Use tuples to store fixed data, and explain when a tuple is a better choice than a list.
#
# ### What to do
# 1. Create a tuple called `location` that stores a latitude and a longitude, for example `(33.2148, -97.1331)`. Print the tuple.
# 2. Print the **first** item and the **second** item of `location` separately using indexing.
# 3. Create a tuple called `course_meeting` with three items: a day, a time, and a place (for example `"Monday"`, `"6:30 PM"`, `"Zoom"`). Print each item on its own line.
# 4. The code cell provides a list `favorite_foods = ["pizza", "pasta", "salad"]`. Change the second item to `"sushi"` using indexing and print the updated list. This shows a list **can** be changed.
# 5. Add a **comment** answering: why would trying to change an item in `location` (a tuple) cause an error? (One short sentence.)
# 6. In the markdown cell below the code cell, answer in your own words: **give one real-world example of data that should be stored in a tuple, and explain why.**
#
# ### Hints
# - Create a tuple with parentheses: `my_tuple = (1, 2, 3)`.
# - A tuple is ordered but **not changeable**; a list is ordered and **changeable**.
# - `location[0]` is the first item, `location[1]` is the second.

# %%
favorite_foods = ["pizza", "pasta", "salad"]
my_tuple = (1, 2, 3)

# 1 create a tuple location that stores latitude and longitude
location = (33.2148, -97.1331)

# 2 print first and second items seperately using index
print(location[0])
print(location[1])

# 3 create a tuple course_meeting and print
course_meeting = ("Monday", "6:30 PM", "Zoom")
print(course_meeting[0])
print(course_meeting[1])
print(course_meeting[2])

# 4 change second item to sushi
favorite_foods[1] = "sushi"
print(favorite_foods)

# 5 changing an item in location would cause an error because tuples are immutable
# Out:
# 33.2148
# -97.1331
# Monday
# 6:30 PM
# Zoom
# ['pizza', 'sushi', 'salad']

# %% [markdown]
# **Question 2.6 — Your written answer:**
#
# *Give one real-world example of data that should be stored in a tuple, and explain why. (One example of data that should be stored in a tuple is a students transcript. It is a set of courses with the grade earned and does not ever change.)*

# %% [markdown]
# ## Question 3 — Sets, Set Operations, and Boolean Values  *(13 points)*
#
# Use sets to manage unique items and compare groups, and use Boolean values to check conditions.
#
# ### What to do
# 1. A sign-in list with repeated names is provided: `attendees = ["Anna", "John", "Sara", "Anna", "John", "Lina"]`. Convert it to a **set** to keep only the unique names, store it in `unique_attendees`, and print both the original list and the set.
# 2. Two groups are provided in the code cell:
#    - `python_students = {"Anna", "John", "Sara", "Reza"}`
#    - `data_students = {"Sara", "Reza", "Lina", "Omid"}`
#
#    Print each of the following, labeled:
#    - all unique students in **either** group (`union`)
#    - students in **both** groups (`intersection`)
#    - students in `python_students` but **not** in `data_students` (`difference`)
# 3. **Boolean values:** A student can enter the lab if they are **at least 18 years old** AND have a **student ID**. Using the variables `age = 20` and `has_student_id = True`, create a Boolean called `can_enter_lab` that is `True` only when **both** conditions are met, and print it.
# 4. **Membership and subset:** Create a set `project_team = {"Sara", "Reza"}`. Print the result of `project_team.issubset(python_students)`, and print the result of `"Anna" in python_students`.
# 5. Add a **comment** answering: what is the difference between `union` and `intersection`? (One short sentence.)
#
# ### Hints
# - Make a set from a list with `set(my_list)` — duplicates are removed automatically.
# - `a.union(b)`, `a.intersection(b)`, and `a.difference(b)` compare two sets.
# - `and` requires **both** sides to be `True`.
# - `issubset()` returns `True` when every item of the first set is in the second.

# %%
attendees = ["Anna", "John", "Sara", "Anna", "John", "Lina"]
python_students = {"Anna", "John", "Sara", "Reza"}
data_students = {"Sara", "Reza", "Lina", "Omid"}
age = 20
has_student_id = True

# 1 Convert list to set to remove duplicates
attendees = ["Anna", "John", "Sara", "Anna", "John", "Lina"]
unique_attendees = set(attendees)
print("Original list:", attendees)
print("Unique attendees:", unique_attendees)

# 2 Set operations
python_students = {"Anna", "John", "Sara", "Reza"}
data_students   = {"Sara", "Reza", "Lina", "Omid"}

print("Union (either group):       ", python_students.union(data_students))
print("Intersection (both groups): ", python_students.intersection(data_students))
print("Difference (python only):   ", python_students.difference(data_students))

# 3 Boolean: student can enter if age >= 18 AND has student ID
age = 20
has_student_id = True
can_enter_lab = (age >= 18) and has_student_id
print("Can enter lab:", can_enter_lab)

# 4 Membership and subset
project_team = {"Sara", "Reza"}
print("project_team is subset of python_students:", project_team.issubset(python_students))
print("'Anna' in python_students:               ", "Anna" in python_students)

# 5 Union vs. intersection:
# Union gives every item that appears in either set; intersection gives only items that appear in both.
# Write your answer here
# Out:
# Original list: ['Anna', 'John', 'Sara', 'Anna', 'John', 'Lina']
# Unique attendees: {'John', 'Sara', 'Lina', 'Anna'}
# Union (either group):        {'Anna', 'Sara', 'Reza', 'Omid', 'John', 'Lina'}
# Intersection (both groups):  {'Sara', 'Reza'}
# Difference (python only):    {'John', 'Anna'}
# Can enter lab: True
# project_team is subset of python_students: True
# 'Anna' in python_students:                True

# %% [markdown]
# ## Question 4 — Dictionaries and List Comprehension  *(12 points)*
#
# Store key–value data in a dictionary and use list comprehension to pull information out of it.
#
# ### What to do
# A nested dictionary of students is provided in the code cell. Each student has a `grade` and a list of `courses`:
#
# ```python
# students = {
#     "Anna": {"grade": 92, "courses": ["Python", "Statistics"]},
#     "John": {"grade": 76, "courses": ["Python", "Math"]},
#     "Sara": {"grade": 88, "courses": ["AI", "Python"]},
#     "Lina": {"grade": 65, "courses": ["Math", "Statistics"]},
#     "Reza": {"grade": 95, "courses": ["AI", "Python"]}
# }
# ```
#
# 1. **Access:** Print Anna's grade, and print Sara's first course (the item at index 0 of her course list).
# 2. **Add and update:** Add a new student `"Mike"` with a grade of `81` and courses `["Python", "AI"]`. Then update Lina's grade to `70`. Print the full dictionary afterward.
# 3. **List comprehension — passing students:** Assume a passing grade is **70 or higher**. Use a list comprehension to build a list called `passed_students` containing the **names** of all students who passed, then print it.
# 4. **List comprehension — by course:** Use a list comprehension to build a list called `python_students` containing the **names** of all students who have `"Python"` in their course list, then print it.
# 5. **Slicing:** Print only the **first three** names from `passed_students` using slicing.
# 6. Add a **comment** answering: what does `students.items()` give you when you loop over it? (One short sentence.)
#
# ### Hints
# - Access a nested value with two keys: `students["Anna"]["grade"]`.
# - Add or update with `students["Mike"] = {...}` and `students["Lina"]["grade"] = 70`.
# - List comprehension format: `[name for name, info in students.items() if info["grade"] >= 70]`.
# - Check membership in a list with `"Python" in info["courses"]`.
# - Slicing: `passed_students[:3]` gives the first three items.

# %%
students = {
    "Anna": {"grade": 92, "courses": ["Python", "Statistics"]},
    "John": {"grade": 76, "courses": ["Python", "Math"]},
    "Sara": {"grade": 88, "courses": ["AI", "Python"]},
    "Lina": {"grade": 65, "courses": ["Math", "Statistics"]},
    "Reza": {"grade": 95, "courses": ["AI", "Python"]}
}

# Write your answer here
students = {
    "Anna": {"grade": 92, "courses": ["Python", "Statistics"]},
    "John": {"grade": 76, "courses": ["Python", "Math"]},
    "Sara": {"grade": 88, "courses": ["AI", "Python"]},
    "Lina": {"grade": 65, "courses": ["Math", "Statistics"]},
    "Reza": {"grade": 95, "courses": ["AI", "Python"]}
}

# 1 Access
print("Anna's grade:      ", students["Anna"]["grade"])
print("Sara's first course:", students["Sara"]["courses"][0])

# 2 Add Mike and update Lina's grade
students["Mike"] = {"grade": 81, "courses": ["Python", "AI"]}
students["Lina"]["grade"] = 70
print("\nUpdated dictionary:")
for name, info in students.items():
    print(f"  {name}: {info}")

# 3 List comprehension: students with grade >= 70
passed_students = [name for name, info in students.items() if info["grade"] >= 70]
print("\nPassed students:", passed_students)

# 4 List comprehension: students enrolled in Python
python_students = [name for name, info in students.items() if "Python" in info["courses"]]
print("Python students:", python_students)

# 5 First three names from passed_students
print("First three passed:", passed_students[:3])

# 6 What students.items() gives you when looping:
# It yields each key-value pair as a (name, info) tuple, so you can access both at once in the loop.
# Out:
# Anna's grade:       92
# Sara's first course: AI
#
# Updated dictionary:
#   Anna: {'grade': 92, 'courses': ['Python', 'Statistics']}
#   John: {'grade': 76, 'courses': ['Python', 'Math']}
#   Sara: {'grade': 88, 'courses': ['AI', 'Python']}
#   Lina: {'grade': 70, 'courses': ['Math', 'Statistics']}
#   Reza: {'grade': 95, 'courses': ['AI', 'Python']}
#   Mike: {'grade': 81, 'courses': ['Python', 'AI']}
#
# Passed students: ['Anna', 'John', 'Sara', 'Lina', 'Reza', 'Mike']
# Python students: ['Anna', 'John', 'Sara', 'Reza', 'Mike']
# First three passed: ['Anna', 'John', 'Sara']
