# %% [markdown]
# <a href="https://colab.research.google.com/github/condron78/JoannCondron_DTSC3020_summer2026/blob/main/inclass_exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome")
# Out:
# welcome
